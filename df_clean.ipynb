# %%
import pandas as pd

data_old = pd.read_csv('./US_AQI_Chopped.csv')

data_old
# Out:
# /Users/greerinns/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (2,4,5,7,8,9,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Unnamed: 0  CBSA Code      Date   AQI Category Defining Parameter  \
# 0               0.0    10140.0  1/1/2022  21.0     Good              PM2.5
# 1               1.0    10140.0  1/2/2022  12.0     Good              PM2.5
# 2               2.0    10140.0  1/3/2022  18.0     Good              PM2.5
# 3               3.0    10140.0  1/4/2022  19.0     Good              PM2.5
# 4               4.0    10140.0  1/5/2022  17.0     Good              PM2.5
# ...             ...        ...       ...   ...      ...                ...
# 1048570         NaN        NaN       NaN   NaN      NaN                NaN
# 1048571         NaN        NaN       NaN   NaN      NaN                NaN
# ...

# %%
data_old = data_old.drop(['Unnamed: 0'], axis=1)

# %%
data_old = data_old.dropna()

# %%
data_old
# Out:
#         CBSA Code        Date   AQI Category Defining Parameter  \
# 0         10140.0    1/1/2022  21.0     Good              PM2.5
# 1         10140.0    1/2/2022  12.0     Good              PM2.5
# 2         10140.0    1/3/2022  18.0     Good              PM2.5
# 3         10140.0    1/4/2022  19.0     Good              PM2.5
# 4         10140.0    1/5/2022  17.0     Good              PM2.5
# ...           ...         ...   ...      ...                ...
# 192459    49740.0  12/27/2021  34.0     Good              PM2.5
# 192460    49740.0  12/28/2021  34.0     Good              Ozone
# 192461    49740.0  12/29/2021  35.0     Good              Ozone
# 192462    49740.0  12/30/2021  27.0     Good              Ozone
# 192463    49740.0  12/31/2021  27.0     Good              Ozone
#
#         Number of Sites Reporting city_ascii state_id  state_name      lat  \
# 0                             2.0   Aberdeen       WA  Washington  46.9757
# ...

# %%
data_old.dtypes
# Out:
# CBSA Code                    float64
# Date                          object
# AQI                          float64
# Category                      object
# Defining Parameter            object
# Number of Sites Reporting    float64
# city_ascii                    object
# state_id                      object
# state_name                    object
# lat                          float64
# lng                          float64
# population                   float64
# density                      float64
# timezone                      object
# dtype: object

# %%
data_old['CBSA Code'] = data_old['CBSA Code'].astype(int)
data_old['Number of Sites Reporting'] = data_old['Number of Sites Reporting'].astype(int)
data_old['population'] = data_old['population'].astype(int)
data_old['density'] = data_old['density'].astype(int)
# Out:
# /Users/greerinns/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/greerinns/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/greerinns/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
data_old
# Out:
#         CBSA Code        Date   AQI Category Defining Parameter  \
# 0           10140    1/1/2022  21.0     Good              PM2.5
# 1           10140    1/2/2022  12.0     Good              PM2.5
# 2           10140    1/3/2022  18.0     Good              PM2.5
# 3           10140    1/4/2022  19.0     Good              PM2.5
# 4           10140    1/5/2022  17.0     Good              PM2.5
# ...           ...         ...   ...      ...                ...
# 192459      49740  12/27/2021  34.0     Good              PM2.5
# 192460      49740  12/28/2021  34.0     Good              Ozone
# 192461      49740  12/29/2021  35.0     Good              Ozone
# 192462      49740  12/30/2021  27.0     Good              Ozone
# 192463      49740  12/31/2021  27.0     Good              Ozone
#
#         Number of Sites Reporting city_ascii state_id  state_name      lat  \
# 0                               2   Aberdeen       WA  Washington  46.9757
# ...

# %%
data_old.to_csv('load_to_pg.csv', index=False)
